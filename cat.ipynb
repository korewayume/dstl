# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from dstl.data_util import data_store
from dstl.preprocessing import clip_to_tile, truncate_as_float32
from keras.utils.np_utils import to_categorical
# Out:
# Using TensorFlow backend.

# %%
image = truncate_as_float32(data_store.raster_image('6100_1_3', 'C'))
mask = data_store.mask_for_image_and_class('6100_1_3', 'C')
image_tile = clip_to_tile(image, (512, 512))
mask_tile = clip_to_tile(mask, (512, 512))
print("image_tile shape: ", image_tile.shape)
print("mask_tile shape: ", mask_tile.shape)
# Out:
# image_tile shape:  (7, 7, 512, 512, 3)
# mask_tile shape:  (7, 7, 512, 512)

# %%
plt.imshow(mask_tile[6,6])

# %%
plt.imshow(mask)
